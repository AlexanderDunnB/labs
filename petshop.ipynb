# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderDunnB/labs/blob/main/petshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The entities in my diagram are: Food, enclosure, Pets, Customer, Loyalty points, and transaction. Food hass a connection to pets and transaction. The food is fed to the pets and sold through transactions. Pets has connections to food, transactions, and enclosures. Pets eat the food, are kept in enclosures, and are sold in transactions. Loyalty points only connection is to Customer because the customer is the only one who can "Verb" the loyalty points. in this case one and only one customer collects anywhere from zero to one million loyalty points. for the pets to transactions relationship I stated that between one and twelve pets would be sold in one and only one transaction. I said one and only one transaction assuming that the pet could only be sold once and that the store has no return policy.

# %% [markdown]
# ![Untitled Diagram.png](data:image/png;base64,...)
